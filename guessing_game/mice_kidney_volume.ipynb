# %% [markdown]
# ## This exercise examines total kidney volume (in cubic mm) from MR Images of a mice.
# ### For the first part of this experiment, we are going to use their mask file, then move onto their original image file and use neural networks.
#
# ##### There are 50 datasets for this experiment

# %% [markdown]
# ####  First we are going to load the necessary libraries and packages to start with.
#
# $ numpy,matplotlib,pandas,nibabel,os $

# %%
import nibabel as nib
import os
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# #### Next we will check the directory for images, and going to see the name of the files just for our confirmation.

# %%
basepath = 'Data'
for entry in os.listdir(basepath):
    if os.path.isfile(os.path.join(basepath, entry)):
        print(entry)
        
# basepath is given above 
kidneyprefix = 'label.nii.gz' #your file name (last part of file name)
strremove = -len(kidneyprefix) # why negative here? 
strremove
# Out:
# 7_Bl6_m_RC_tk16_18wk_M31_Exp004_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk23_18wk_M31_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk23_12wk_Lo1_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk15_12wk_Lo1_Exp005_Pro001avw-label.nii.gz
# 7_F1_m_RC_tk01_18weeks_M11_Exp005_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk06_3wk_Kl1_Exp008_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk13_12wk_Lo1_Exp005_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk14_18wk_M31_Exp007_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk19_18wk_M41_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk18_12wk_Lp1_Exp007_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk19_18wk_M41_Exp006_Pro001avw-label.nii.gz
# 7_F1_m_RC_tk01_3wk_Kl1_Exp007_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk13_18wk_M31_Exp006_Pro001avw.nii.gz
# 7_BL6_m_wt_tk15_3wk_Km1_Exp007_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk17_6wk_KI1_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk23_18wk_M31_Exp006_Pro001avw.nii.gz
# 7_F1_m_RC_tk01_18weeks_M11_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk07_18wk_M41_Exp005_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk12_6wk_KH1_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk14_12wk_Lo1_Exp006_Pro001avw-label.nii.gz
# 7_BL6_m_RC_tk16_3wk_Kn1_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk20_6wk_KI1_Exp005_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk15_6wk_KI1_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk14_6wk_KH1_Exp007_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk23_12wk_Lo1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk15_6wk_KI1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk23_3wk_Kq1_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk15_18wk_M31_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk18_18wk_M41_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk20_18wk_M81_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk12_18wk_M31_Exp006_Pro001avw.nii.gz
# 7_BL6_m_WT_tk14_3wk_Km1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk13_6wk_KH1_Exp005_Pro001avw.nii.gz
# 7_BL6_wt_M_tk13_3wk_Km1_Exp007_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk12_12wk_Lo1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk16_6wk_KH1_Exp006_Pro001avw-label.nii.gz
# 7_BL6_m_wt_tk12_3wk_Km1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk19_6wk_KI1_Exp005_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk12_6wk_KH1_Exp006_Pro001avw.nii.gz
# 7_BL6_m_RC_tk17_3wk_Kn1_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk18_6wk_KI1_Exp005_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk14_6wk_KH1_Exp007_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk13_6wk_KH1_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk18_18wk_M41_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_Rc_tk17_12wk_Lp1_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk06_18wk_M41_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk07_18wk_M41_Exp005_Pro001avw-label.nii.gz
# 7_F1_m_RC_tk01_6wk_KF1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk19_6wk_KI1_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk07_12wk_Lq1_Exp005_Pro001avw-label.nii.gz
# 7_F1_m_RC_tk01_12wk_Lo1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_Rc_tk17_12wk_Lp1_Exp005_Pro001avw.nii.gz
# 7_BL6_m_RC_tk16_3wk_Kn1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk23_3wk_Kq1_Exp005_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk07_12wk_Lq1_Exp005_Pro001avw.nii.gz
# 7_BL6_m_wt_tk12_3wk_Km1_Exp006_Pro001avw-label.nii.gz
# 7_BL6_m_RC_tk07_3wk_Kl1_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk18_6wk_KI1_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk18_3wk_Kn1_Exp006_Pro001avw-label.nii.gz
# 7_BL6_m_WT_tk14_3wk_Km1_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk18_3wk_Kn1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk13_18wk_M31_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk06_18wk_M41_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk06_6wk_KG1_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk17_18wk_M41_Exp005_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk20_12wk_Lp1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk20_6wk_KI1_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk19_3wk_Kn1_Exp007_Pro001avw.nii.gz
# 7_BL6_m_RC_tk17_3wk_Kn1_Exp005_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk20_18wk_M81_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk19_3wk_Kn1_Exp007_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk14_12wk_Lo1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk06_3wk_Kl1_Exp008_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk14_18wk_M31_Exp007_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk15_18wk_M31_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk23_6wk_KI1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_WT_tk12_12wk_Lo1_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk12_18wk_M31_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk18_12wk_Lp1_Exp007_Pro001avw.nii.gz
# 7_F1_m_RC_tk01_3wk_Kl1_Exp007_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk06_6wk_KG1_Exp006_Pro001avw.nii.gz
# 7_BL6_wt_M_tk13_3wk_Km1_Exp007_Pro001avw-label.nii.gz
# 7_BL6_m_wt_tk15_3wk_Km1_Exp007_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk20_3wk_Kn1_Exp005_Pro001avw.nii.gz
# 7_BL6_m_RC_tk07_3wk_Kl1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk20_3wk_Kn1_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk17_18wk_M41_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk23_6wk_KI1_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk06_12wk_Lq1_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk17_6wk_KI1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk20_12wk_Lp1_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk13_12wk_Lo1_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_WT_tk15_12wk_Lo1_Exp005_Pro001avw.nii.gz
# 7_F1_m_RC_tk01_6wk_KF1_Exp006_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk07_6wk_KG1_Exp005_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk07_6wk_KG1_Exp005_Pro001avw-label.nii.gz
# 7_Bl6_m_RC_tk06_12wk_Lq1_Exp005_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk16_6wk_KH1_Exp006_Pro001avw.nii.gz
# 7_Bl6_m_RC_tk16_18wk_M31_Exp004_Pro001avw.nii.gz
# 7_F1_m_RC_tk01_12wk_Lo1_Exp006_Pro001avw-label.nii.gz
# -12

# %% [markdown]
# #### Next one is couple of steps at one go
#
# #### first we read the files
# #### then we loop through the pictures
# #### this gives all the header information about the image, then we calculate tkv

# %%
subdir, dirs, files = os.walk(basepath).__next__()
files = [k for k in files if kidneyprefix in k]
df = pd.DataFrame(columns=['filename', 'tkv_in_cubicmm'])
#Loop through files
for filename in files:
 
    kidneyimage = nib.load(basepath+'/'+ filename) # to open other image from same subject: segimage = nib.load(input_folder+'\\'+ filename[:strremove]+'endFileName.nii.gz')
    kidneydata_label = kidneyimage.get_fdata()
    info = kidneyimage.affine 
    
    #change all the images to 1, sum all the 1s, and calculate using volume from info
    kidneydata_label[kidneydata_label>0]= 1 #gray and white into 1
    tkv=np.sum(kidneydata_label)
#    next we are going to use absolute value, because there are some (-) which shows direction
    voxel_volume=np.abs(info[0,0]*info[1,2]*info[2,1]) 
#    the logic is that we get the actual volume by multiplying 
    tkv_cubic_mm=tkv*voxel_volume
#     pr
    df_new=pd.DataFrame([[filename,tkv_cubic_mm]], columns=['filename', 'tkv_in_cubicmm'])
    df=df.append(df_new, ignore_index=True)
    
#     df.append({filename:tkv_cubic_mm},ignore_index=True)
    
    #plot mid slice
    #calculate kidney volumes from segmentation (mask) files

# %%
df
# Out:
#                                              filename  tkv_in_cubicmm
# 0   7_Bl6_m_RC_tk16_18wk_M31_Exp004_Pro001avw-labe...      732.139922
# 1   7_Bl6_m_WT_tk23_18wk_M31_Exp006_Pro001avw-labe...      344.899963
# 2   7_Bl6_m_WT_tk23_12wk_Lo1_Exp006_Pro001avw-labe...      372.159960
# 3   7_Bl6_m_WT_tk15_12wk_Lo1_Exp005_Pro001avw-labe...      357.059962
# 4   7_Bl6_m_RC_tk06_3wk_Kl1_Exp008_Pro001avw-label...      176.562476
# 5   7_Bl6_m_WT_tk14_18wk_M31_Exp007_Pro001avw-labe...      415.869955
# 6   7_Bl6_m_RC_tk18_12wk_Lp1_Exp007_Pro001avw-labe...      533.799943
# 7   7_Bl6_m_RC_tk19_18wk_M41_Exp006_Pro001avw-labe...      525.169944
# 8   7_Bl6_m_RC_tk17_6wk_KI1_Exp006_Pro001avw-label...      503.119946
# 9   7_F1_m_RC_tk01_18weeks_M11_Exp005_Pro001avw-la...     1157.529876
# 10  7_Bl6_m_WT_tk12_6wk_KH1_Exp006_Pro001avw-label...      332.129964
# 11  7_Bl6_m_WT_tk14_12wk_Lo1_Exp006_Pro001avw-labe...      379.409959
# 12  7_BL6_m_RC_tk16_3wk_Kn1_Exp006_Pro001avw-label...      212.243623
# 13  7_Bl6_m_WT_tk15_6wk_KI1_Exp006_Pro001avw-label...      314.069966
# 14  7_Bl6_m_WT_tk23_3wk_Kq1_Exp005_Pro001avw-label...      172.930885
# 15  7_Bl6_m_WT_tk15_18wk_M31_Exp006_Pro001avw-labe...      370.799960
# 16  7_Bl6_m_RC_tk18_18wk_M41_Exp006_Pro001avw-labe...      541.159942
# 17  7_Bl6_m_RC_tk16_6wk_KH1_Exp006_Pro001avw-label...      438.459953
# 18  7_BL6_m_RC_tk17_3wk_Kn1_Exp005_Pro001avw-label...      204.254122
# 19  7_Bl6_m_WT_tk14_6wk_KH1_Exp007_Pro001avw-label...      319.149966
# 20  7_Bl6_m_WT_tk13_6wk_KH1_Exp005_Pro001avw-label...      352.079962
# 21  7_Bl6_m_Rc_tk17_12wk_Lp1_Exp005_Pro001avw-labe...      571.739939
# 22  7_Bl6_m_RC_tk07_18wk_M41_Exp005_Pro001avw-labe...      559.129940
# 23  7_Bl6_m_RC_tk19_6wk_KI1_Exp005_Pro001avw-label...      417.659955
# 24  7_Bl6_m_RC_tk07_12wk_Lq1_Exp005_Pro001avw-labe...      577.129938
# 25  7_BL6_m_wt_tk12_3wk_Km1_Exp006_Pro001avw-label...      135.540753
# 26  7_BL6_m_RC_tk07_3wk_Kl1_Exp006_Pro001avw-label...      171.051002
# 27  7_Bl6_m_RC_tk18_6wk_KI1_Exp005_Pro001avw-label...      421.879955
# 28  7_Bl6_m_RC_tk18_3wk_Kn1_Exp006_Pro001avw-label...      114.648422
# 29  7_BL6_m_WT_tk14_3wk_Km1_Exp006_Pro001avw-label...      216.357392
# 30  7_Bl6_m_WT_tk13_18wk_M31_Exp006_Pro001avw-labe...      396.759958
# 31  7_Bl6_m_RC_tk06_18wk_M41_Exp006_Pro001avw-labe...      561.739940
# 32  7_Bl6_m_RC_tk06_6wk_KG1_Exp006_Pro001avw-label...      446.129952
# 33  7_Bl6_m_RC_tk20_6wk_KI1_Exp005_Pro001avw-label...      459.559951
# 34  7_Bl6_m_RC_tk20_18wk_M81_Exp006_Pro001avw-labe...      516.729945
# 35  7_Bl6_m_RC_tk19_3wk_Kn1_Exp007_Pro001avw-label...      188.195775
# 36  7_Bl6_m_WT_tk12_12wk_Lo1_Exp006_Pro001avw-labe...      315.919966
# 37  7_Bl6_m_WT_tk12_18wk_M31_Exp006_Pro001avw-labe...      353.789962
# 38  7_F1_m_RC_tk01_3wk_Kl1_Exp007_Pro001avw-label....      276.967159
# 39  7_BL6_wt_M_tk13_3wk_Km1_Exp007_Pro001avw-label...      186.590551
# 40  7_BL6_m_wt_tk15_3wk_Km1_Exp007_Pro001avw-label...      101.794420
# 41  7_Bl6_m_RC_tk20_3wk_Kn1_Exp005_Pro001avw-label...      183.917211
# 42  7_Bl6_m_RC_tk17_18wk_M41_Exp005_Pro001avw-labe...      565.709939
# 43  7_Bl6_m_WT_tk23_6wk_KI1_Exp006_Pro001avw-label...      332.049964
# 44  7_Bl6_m_RC_tk06_12wk_Lq1_Exp005_Pro001avw-labe...      423.329955
# 45  7_Bl6_m_RC_tk20_12wk_Lp1_Exp006_Pro001avw-labe...      529.679943
# 46  7_Bl6_m_WT_tk13_12wk_Lo1_Exp005_Pro001avw-labe...      347.069963
# 47  7_F1_m_RC_tk01_6wk_KF1_Exp006_Pro001avw-label....      651.729930
# 48  7_Bl6_m_RC_tk07_6wk_KG1_Exp005_Pro001avw-label...      408.429956
# 49  7_F1_m_RC_tk01_12wk_Lo1_Exp006_Pro001avw-label...     1466.549843

# %%
df.tkv_in_cubicmm.describe(), df.tkv_in_cubicmm.median()
# Out:
# (count      50.000000
#  mean      413.055637
#  std       239.806387
#  min       101.794420
#  25%       286.242861
#  50%       375.784960
#  75%       523.059944
#  max      1466.549843
#  Name: tkv_in_cubicmm, dtype: float64,
#  375.78495974897623)

# %% [markdown]
# ### Trying to build a model

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
tf.__version__
# Out:
# '2.4.1'

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('Data',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 0 images belonging to 0 classes.
